# %% [markdown]
# # Data Science Visualization - Matplotlib

# %% [markdown]
# ## Tasks Today:
#
# 1) <b>Matplotlib</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Data Visulation <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Importing <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Different Types of Charts <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Basics <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Customization <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Axis Labels & Line Marks <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Legend & Line Labels <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Subplots <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) <b>In-Class Exercise #1</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; g) Presentation Worthiness <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; h) <b>In-Class Exercise #2</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; i) Box Plot <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; j) Scatter Plot <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; k) Histograms <br>

# %% [markdown]
# ### Data Visualization <br>
# <p>Data visualization is one of the most powerful tools an analyst has for two main reasons. Firstly, it is unrivalled in it's ability to guide the analysts hand in determining 'what to look at next'. Often a visual is revealing of patterns in the data that are not easily discernable by just looking at dataframes. Secondly, they are an analysts greatest communication tool. Very often professional analysts need to present their results to groups of people responsible for taking action based on what the data says. Visuals can tell your story much better then raw numbers, so let's talk a little bit about how to make effective visuals that make a point.</p>

# %% [markdown]
# ##### Importing

# %%
# !pip install matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # standard

# %% [markdown]
# ### Different Types of Charts <br>
# <ul>
#     <li><b>Line Chart:</b> Exploring data over time</li>
#     <li><b>Bar Chart:</b> Comparing categories of data and tracks changes over time</li>
#     <li><b>Pie Chart:</b> Explore parts of a whole, i.e. fractions</li>
#     <li><b>Scatter Plot:</b> Similar to line charts, track correlations between two categories</li>
#     <li><b>Histogram:</b> Unrelated from bar charts, show distribution of variables</li>
#     <li><b>Candlestick Chart:</b> Used a lot in financial sector, i.e. can compare a stock over a period of time</li>
#     <li><b>Box Chart:</b> Looks identical to candlestick charts, compares minimum, 1st, medium, 3rd quartiles, and max values</li>
# </ul>
#
# <p>Depending on what you need to accomplish in conceptualizing your data, you will go with a specific type of chart to portray your data.</p>

# %% [markdown]
# ### Basics <br>
# <p>Plots can be as detailed as you'd like them to be, but the simplest plot to start with can be done in just a few lines:</p>

# %%
plt.plot([12,12,9,9,6,2,2,4])
plt.show()

# %% [markdown]
# ### Customization <br>
# <p>There's many customizable options when using Matplotlib, such as; line types, colors, labels, figure size, etc. We'll go over a few of them here:</p>

# %% [markdown]
# ##### Axis Labels & Line Marks

# %%
plt.plot([1,2,3,4,5],[23,45,72,78,90], 'yo-')
plt.plot([3,4,5,6,7,8], [22,33,90,60,110,105], 'rx:')
plt.xlabel('Increase Time')
plt.ylabel('Increase Value')
plt.show()

# %% [markdown]
# ##### Legend & Line Labels

# %%
plt.plot([1600,1700,1800,1900,2000],[1,1.4,1.6,1.8,2], 'ro-', label='Demographic 1')
plt.plot([1600,1700,1800,1900,2000], [2,2,3,3.1,2.4], 'gx-', label='Demographic 2')
plt.ylabel('Population (Billions)')
plt.xlabel('Year')
plt.legend()
plt.show()

# %% [markdown]
# ### Subplots <br>
# <p>Using the subplots method, you're able to create multiple plots within a single cell.</p>

# %%
# first plot
plot_1 = plt.subplot(2,1,1) # 2 columns, 1 row, display in the first panel of my output (all the way on the left)

plt.plot([1600,1700,1800,1900,2000], [1,1.5,1.6,1.8,2], 'ro-', label='Demo-1')
plot_1.set_xlim([1500,2050]) # set a [lower,upper] bound for x axis
plot_1.set_ylim([0,5])
plt.ylabel('Populations (Billions)')
plt.xlabel('Years')
plt.legend()


# second plot
plot_2 = plt.subplot(2,1,2) # same height/width as above -- display in position #2 (right of first plot)
plt.plot([1600,1700,1800,1900,2000], [0.5,2,2.2,2.8,4], 'gx-', label='Demo-2')
plot_2.set_xlim([1500,2050]) # set a [lower,upper] bound for x axis
plot_2.set_ylim([0,5])
# additonal keyword args to note... rotation (rotates the label by n degrees), 
# labelpad (gives us some spacing between axis label and axis values)
plt.ylabel('Populations (Billions)', rotation = 0, labelpad = 55)
plt.xlabel('Years')
plt.legend()
# hspace from subplots_adjust gives us padding heightwise between subplots
plt.subplots_adjust(hspace = 1)

# %% [markdown]
# ### In-Class Exercise #1 - Create a Graph that Depicts y = x**2

# %%
import numpy as np

# y = x**2
# use matplotlib/ np to plot y = x**2
x = np.arange(-5,6)
y = x**2

# plt.plot(x,y,'go-')

def squared(x):
    return x**2


plt.plot(x,squared(x), 'go-')

# %% [markdown]
# ### Presentation Worthiness
# <p>Before we go into how to use this as a tool for data exploration, let's talk quickly about presentation-worthiness. In the next cell we're going to introduce customization of lines, colors, ticks, titles, fonts, and grids.</p>

# %%
x = np.arange(-5,6)
y = x**2
fig, ax = plt.subplots(figsize=(20,10))

plt.plot(x,y,
        lw = 5, # line width
        ls = '--', # line style
         color = 'r', # line/ data-marker color
         marker = 'o', # data marker
         markersize = 15, # size of marker
         markerfacecolor = 'b', # color of marker (overrides line color)
         label = 'Data f(x) = x^2'
        )

plt.xlabel('X Value', font='Times New Roman', fontsize = 32, labelpad = 25)
plt.ylabel('Y Value', font = 'Times New Roman', fontsize = 32, labelpad = 25)

plt.xticks(fontsize = 28)
plt.yticks(fontsize = 28)

plt.title('Visual of f(x) = x^2', fontname = 'Times New Roman', fontsize = '40', y = 1.05)

plt.grid(True)

plt.legend(fontsize = 28, loc = 'best') # lower,upper, center + left, right, center

# tight layout reshapes plot but keeps relative dimensions, fontsize, etc
plt.tight_layout()

# %% [markdown]
# <p>It's sometimes nice to obsess a little bit over how your plots look. It's good practice paying attention to detail and it has huge payoff when you end up presenting your findings to other analysts and business parteners. Here's a more complex example of using the matplotlib api:</p>

# %%
markers = ['o', 'v', '^', '*', 's']
styles = ['-', '--', '-.', ':', '-']
colors = ['#588C7E', '#F2E394', '#F2AE72', '#D96459', '#8C4646']

# %%
x = np.linspace(0,10,50)

fig, ax = plt.subplots(figsize = (20,10))

# Loop over range of 5 to create 5 separate lines in a line chart

for i in range(5):
    plt.plot(x, x** i,
             lw = 5,
             ls = styles[i],
             color = colors[i],
             marker = markers[i],
             markersize = 15,
             label = f'x^{i}'
    )
    
plt.xlim(0,10)
plt.ylim(0,100)

plt.xlabel('Input Size (n)', font='Times New Roman', fontsize = 32)
plt.ylabel('Time', font='Times New Roman', fontsize = 32)

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.title('Time Complexity Chart', fontname = 'Times New Roman', fontsize = 48, y = 1.05)

plt.legend(fontsize = 32)

plt.tight_layout()

# %% [markdown]
# ### In-Class Exercise #2 - Customize the f(x) Plot Created Earlier <br>
# <p>Customize it however you would like...</p>

# %%
# students to do...

# %% [markdown]
# ### Scatter Plot

# %%
import csv
from  itertools import groupby

file_path = '../files/iris.csv'

plt.figure(figsize = (10.5, 7.25))

def read_csv(filename):
    with open(filename) as f:
        data = list(csv.reader(f))
    return data
    
flowers = read_csv(file_path)
# print(flowers)

# instantiating a dictionary to loop through for coloring later (differentiate flower species by color of markers)

colors = {
    'Iris-setosa': 'red', # DARK BLUE/PURPLISH COLOR
    'Iris-versicolor': 'g',
    'Iris-virginica': 'purple'
}


for species, group in groupby(flowers, lambda x: x[4]):
    flower_cat = list(group)
    sepal_length = [float(flower[0]) for flower in flower_cat]
    sepal_width = [float(flower[1]) for flower in flower_cat]
    plt.scatter(sepal_length, sepal_width, s = 10, c = colors[species], label = species)
    

plt.title('Iris Data Sepal Length x Width', fontsize = 18, y = 1.05)
plt.xlabel('Sepal Length (cm)', fontsize = 10)
plt.ylabel('Sepal Width (cm)', fontsize = 10)

plt.legend(loc = 'best').get_frame().set_color('goldenrod')

# %% [markdown]
# ### Box Plot

# %%
from itertools import groupby

fig = plt.figure(figsize = (10.5,7.25))

flowers = read_csv(file_path)

petal_length = []

for species, group in groupby(flowers, lambda x: x[4]):
    petal_length.append([float(petal[2]) for petal in group])

plt.boxplot(petal_length)

plt.axis([0,4,0,10]) # xmin, xmax, ymin, ymax
plt.xticks([1,2,3], ['Setosa', 'Versicolor', 'Virginica'])
plt.title('Box Plot with Iris Dataset', fontsize =16, loc = 'right')

plt.ylabel('Petal Length (cm)', fontsize = 14)
plt.xlabel('Flower Variety', fontsize = 14)

plt.show()

# Save figure or plot as a .png to the files folder
fig.savefig('../files/iris_petal_bp.png')

# %% [markdown]
# ### Histograms <br>
# <p>While line plots are great for visualizing trends in time series data, histograms are the king of visualizing distributions. Often, the distribution of a variable is what you're interested in, and a visualization provides a lot more information than a group of summary statistics.</p>

# %%
fig, ax = plt.subplots(figsize=(16,9))# Subplots makes a call in the background to create a plot area

# generate random data
data = np.random.uniform(0,10,100)

# Plotting the histogram
plt.hist(data, bins=10, label = 'Data', color = 'r', alpha = 0.5)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.xlabel('Value', fontsize = 35, fontname = 'Times New Roman')
plt.ylabel('Frequency', fontname = 'Times New Roman', fontsize = 35)
plt.legend(loc = 'upper left', fontsize = 30)

# %% [markdown]
# <p>Let's take a look at a mystery/randomly generated DataFrame, and plot the results</p>

# %%
# import pandas as pd
# import numpy as np

def make_mystery_dataframe():
    customer_id = np.random.randint(1000,1200,10000)
    
    states = {1: 'California', 0: 'Colorado'}
    statelist = []
    agelist = []
    
    for i in range(10000):
        ind = np.random.randint(0,2)
        if ind == 0:
            statelist.append(states[ind])
            agelist.append(np.random.normal(loc = 30, scale = 25))
        elif ind == 1:
            statelist.append(states[ind])
            agelist.append(np.random.normal(loc = 40, scale = 30))
    
    mystery_df = pd.DataFrame.from_dict({
        'customer_id': customer_id,
        'ages':agelist,
        'state': statelist
    })
    
    return mystery_df

df = make_mystery_dataframe()
df
# Out:
#       customer_id       ages       state
# 0            1021  32.748627  California
# 1            1038  43.728139    Colorado
# 2            1199  36.921932  California
# 3            1172  46.230366  California
# 4            1100 -40.858769  California
# ...           ...        ...         ...
# 9995         1002   4.798746    Colorado
# 9996         1154  12.684477  California
# 9997         1107  66.013965  California
# 9998         1113  21.856605  California
# 9999         1050 -14.444245    Colorado
#
# [10000 rows x 3 columns]

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (20,10))

#
ax1.hist(df[df['state'] == 'Colorado']['ages'], bins = 80, label = 'Ages in CO')
ax1.set_xlabel('Value', fontname = 'Times New Roman', fontsize = 35)
ax1.set_ylabel('Frequency', fontname='Times New Roman', fontsize = 35)
ax1.tick_params(axis = 'both', labelsize = 30)
ax1.legend(loc = 'best', fontsize = 25)


#
ax2.hist(df[df['state'] == 'California']['ages'], bins = 80, label = 'Ages in CA')
ax2.set_xlabel('Value', fontname = 'Times New Roman', fontsize = 35)
ax2.set_ylabel('Frequency', fontname = 'Times New Roman', fontsize = 35)
ax2.tick_params(axis = 'both', labelsize = 30)
ax2.legend(loc = 'best', fontsize = 25)

# %%
# Out:
# {'Iris-setosa': <itertools._grouper at 0x7f93d10b9f50>,
#  'Iris-versicolor': <itertools._grouper at 0x7f93d10b9ed0>,
#  'Iris-virginica': <itertools._grouper at 0x7f93d10b91d0>}

# %%
# Out:
# 3
